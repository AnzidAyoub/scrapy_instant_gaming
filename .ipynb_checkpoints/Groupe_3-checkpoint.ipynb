# %%
# !scrapy startproject WebCrawler
# Out:
# Error: scrapy.cfg already exists in C:\Users\Anzid\OneDrive\Documents\Dev\python\WebScrapping\WebCrawler

# %%
# !cd WebCrawler && scrapy genspider instantg https://www.instant-gaming.com
# Out:
# Spider 'instantg' already exists in module:
#   WebCrawler.spiders.instantg

# %%
# !cd WebCrawler/WebCrawler/spiders && scrapy crawl instantg -o instant.csv
# Out:
# 2022-10-20 16:11:49 [scrapy.utils.log] INFO: Scrapy 2.7.0 started (bot: WebCrawler)
# 2022-10-20 16:11:49 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.9.10 (tags/v3.9.10:f2f3f53, Jan 17 2022, 15:14:21) [MSC v.1929 64 bit (AMD64)], pyOpenSSL 22.1.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Windows-10-10.0.19044-SP0
# 2022-10-20 16:11:49 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'WebCrawler',
#  'NEWSPIDER_MODULE': 'WebCrawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['WebCrawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2022-10-20 16:11:49 [asyncio] DEBUG: Using selector: SelectSelector
# 2022-10-20 16:11:49 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# ...

# %%
import pandas as pd
lire = pd.read_csv(r"C:\Users\Anzid\OneDrive\Documents\Dev\python\WebScrapping\WebCrawler\WebCrawler\spiders\instant.csv")
lire
# Out:
#     discount                                                img platform  \
# 0       -29%  https://s2.gaming-cdn.com/images/products/1127...     None
# 1       -78%  https://s3.gaming-cdn.com/images/products/1101...     None
# 2       -69%  https://s3.gaming-cdn.com/images/products/1092...     None
# 3       -43%  https://s2.gaming-cdn.com/images/products/1235...     None
# 4       -43%  https://s1.gaming-cdn.com/images/products/1173...     None
# ..       ...                                                ...      ...
# 416      NaN  https://s3.gaming-cdn.com/images/products/4496...     None
# 417     -73%  https://s3.gaming-cdn.com/images/products/4430...     None
# 418     -25%  https://s1.gaming-cdn.com/images/products/4302...     None
# 419      -7%  https://s3.gaming-cdn.com/images/products/4295...     None
# 420     -46%  https://s1.gaming-cdn.com/images/products/4293...     None
#
#       price                   time  \
# 0     7.09€  20/10/2022 ::16:11:50
# ...
